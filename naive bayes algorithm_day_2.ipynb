# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
#getting data set mushroom data set
df=pd.read_csv("/mushrooms.csv")

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
le=LabelEncoder()

# %%
df_encoded=df.apply(le.fit_transform,axis=0)

# %%
df_encoded.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df=df_encoded.values

# %%
x=df[:,1:]
x
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]])

# %%
y=df[:,0]
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %% [markdown]
# 1.posterio probablity
#   1.likely probability
#   2.prior probabilirty

# %%
#prior probablity
def prior_prob(y,label):
    total_examples=y.shape[0]
    class_examples=np.sum(y==label)
    return class_examples/float(total_examples)

# %%
#likely probabilrty
def cond_prob(x_train,y_train,feature_col,feature_val,label):
    x_filtered=x_train[y_train==label]
    numerator=np.sum(x_filtered[:,feature_col]==feature_val)
    denominator=x_filtered.shape[0]
    return numerator/denominator

# %%
#predictions
def predic(x_trian,y_train,x_test):
    classes=np.unique(y_train)
    n_features=x_train.shape[1]
    posterior_prob=[]
    for label in classes:
        likelihood=1.0
        for f in range(n_features):
            cond=cond_prob(x_train,y_train,f,x_test[f],label)
            likelihood=likelihood*cond
        prior=prior_prob(y_train,label)
        posterior=likelihood*prior
        posterior_prob.append(posterior)
    pred=np.argmax(posterior_prob)
    return pred

# %%
def accuracy(x_train,y_train,x_test,y_test):
    pred=[]
    for i in range(x_test.shape[0]):
        pred_label=predic(x_train,y_train,x_test[i])
        pred.append(pred_label)
    y_pred=np.array(pred)
    acc=np.sum(y_pred==y_test)/y_pred.shape[0]
    return acc

# %%
acc=accuracy(x_train,y_train,x_test,y_test)

# %%
acc*100
# Out:
# np.float64(99.63076923076923)
